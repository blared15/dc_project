# %%
import time, os, requests,shutil
import pandas as pd
import concurrent.futures

# %%
def connection_check():
    API = '0a66e9aecdc8c49191309691d8c340b920a060b3'
    endpoint = 'https://cmdb.netledger.com/api/dc-hosts/'
    headers = {'Authorization': 'Token '+ API}
    response = requests.get(endpoint, headers=headers)
    print (response)

# %%
def ip_search (ip):
    API = '0a66e9aecdc8c49191309691d8c340b920a060b3'
    ip = ip
    endpoint = 'https://cmdb.netledger.com/api/ipaddresses/?address={ip}'
    url = endpoint.format(ip=ip)
    headers = {'Authorization': 'Token '+ API}
    response = requests.get(url, headers=headers)
    result = response.json()
    count = result['count']
    if count == 1:
        print(str(ip) + " IP IN CMDB ")
        data['IP in CMDB'][data['IP'] == ip] = 'IP in CMDB'
    elif count < 1:
        print(str(ip) + " IP NOT in CMDB ")

        data['IP in CMDB'][data['IP'] == ip] = 'IP NOT in CMDB'
    elif count > 1:
        print(str(ip) + " IP IN CMDB + ")
        
def dns_search (dns):
    API = '0a66e9aecdc8c49191309691d8c340b920a060b3'
    dns = dns
    endpoint = 'https://cmdb.netledger.com/api/dc-hosts/?hostname={dns}'
    url = endpoint.format(dns=dns)
    headers = {'Authorization': 'Token '+ API}
    response = requests.get(url, headers=headers)
    result = response.json()
    count = result['count']
    if count == 1:
        data['DNS in CMDB'][data['DNS'] == dns] = 'DNS in CMDB'
        print(str(dns)," DNS in cmdb")
    elif count < 1:
        data['DNS in CMDB'][data['DNS'] == dns] = 'DNS NOT in CMDB'
        print(str(dns)," DNS NOT in cmdb")
    elif count > 1:
        data['DNS in CMDB'][data['DNS'] == dns] = 'DNS in CMDB + '
        print(str(dns)," DNS in CMDB +")

# %%
connection_check()
start = time.perf_counter()
filename='SEA_PDUS.xlsx'
workbook = pd.ExcelFile(f'{filename}')
# Out:
# <Response [200]>

# %%
data = pd.read_excel(workbook)

# %%
data['IP in CMDB']=''
data['DNS in CMDB']=''

# %%
with concurrent.futures.ThreadPoolExecutor() as executor:
    executor.map(ip_search, data['IP'])
    executor.map(dns_search, data['DNS'])
# Out:
# 10.30.160.244 IP IN CMDB
# 10.3.178.231 IP IN CMDB
# 10.3.155.245 IP IN CMDB 10.6.155.241 IP IN CMDB 10.3.106.241 IP IN CMDB
#
#
# 10.30.157.242 IP IN CMDB
# 10.30.158.247 IP IN CMDB
# 10.3.178.198 IP IN CMDB
# 10.30.158.240 IP IN CMDB
# 10.6.155.243 IP IN CMDB
# 10.30.158.242 IP IN CMDB
# 10.6.156.243 IP IN CMDB
# /Users/raeniellesunga/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /Users/raeniellesunga/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# pdu-se4-07-08b.sea.netledger.compdu-se4c-02-06c.sea.netledger.com  DNS in cmdb
#   DNS in cmdb
# pdu-se4b-01-02d.sea.netledger.compdu-se4c-02-11a.sea.netledger.com  DNS in cmdb
#  pdu-se4c-02-06a.sea.netledger.com DNS in cmdb
#   DNS in cmdb
# pdu-se4c-01-11c.sea.netledger.com  DNS in cmdb
# pdu-se4-03-02b.sea.netledger.com  DNS in cmdb
# pdu-se4-07-10d.sea.netledger.com  DNS in cmdb
# 10.3.106.244 IP IN CMDB pdu-se4-07-08d.sea.netledger.compdu-se4c-02-05d.sea.netledger.com   DNS in cmdb
#
#  DNS in cmdbpdu-se4b-04-01d.sea.netledger.com
# pdu-se4-05-06a.sea.netledger.com   DNS in cmdb
#  DNS in cmdb
# pdu-se4-05-05b.sea.netledger.com  DNS in cmdb

# %%
with pd.ExcelWriter(f'{filename}') as writer:
    data.to_excel(writer, index=False)

print(f"{filename} has been exported")
stop = time.perf_counter()

print("It took "+str(round((stop-start)/60,2))+" minutes for the script to complete")
# Out:
# SEA_PDUS.xlsx has been exported
# It took 0.02 minutes for the script to complete

# %%
# Out:
# pdu-se4c-01-11c.sea.netledger.com  DNS in cmdb
# /Users/raeniellesunga/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
