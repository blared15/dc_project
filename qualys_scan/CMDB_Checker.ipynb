# %%
import time, os, requests,shutil
import pandas as pd
import concurrent.futures

# %%
def connection_check():
    API = '0a66e9aecdc8c49191309691d8c340b920a060b3'
    endpoint = 'https://cmdb.netledger.com/api/dc-hosts/'
    headers = {'Authorization': 'Token '+ API}
    response = requests.get(endpoint, headers=headers)
    print (response)

# %%
def ip_search (ip):
    API = '0a66e9aecdc8c49191309691d8c340b920a060b3'
    ip = ip
    endpoint = 'https://cmdb.netledger.com/api/ipaddresses/?address={ip}'
    url = endpoint.format(ip=ip)
    headers = {'Authorization': 'Token '+ API}
    response = requests.get(url, headers=headers)
    result = response.json()
    count = result['count']
    if count == 1:
        print(str(ip) + " IP IN CMDB ")
        data['IP in CMDB'][data['IP'] == ip] = 'IP in CMDB'
    elif count < 1:
        print(str(ip) + " IP NOT in CMDB ")

        data['IP in CMDB'][data['IP'] == ip] = 'IP NOT in CMDB'
    elif count > 1:
        print(str(ip) + " IP IN CMDB + ")
        
def dns_search (dns):
    API = '0a66e9aecdc8c49191309691d8c340b920a060b3'
    dns = dns
    endpoint = 'https://cmdb.netledger.com/api/dc-hosts/?hostname={dns}'
    url = endpoint.format(dns=dns)
    headers = {'Authorization': 'Token '+ API}
    response = requests.get(url, headers=headers)
    result = response.json()
    count = result['count']
    if count == 1:
        data['DNS in CMDB'][data['DNS'] == dns] = 'DNS in CMDB'
        print(str(dns)," DNS in cmdb")
    elif count < 1:
        data['DNS in CMDB'][data['DNS'] == dns] = 'DNS NOT in CMDB'
        print(str(dns)," DNS NOT in cmdb")
    elif count > 1:
        data['DNS in CMDB'][data['DNS'] == dns] = 'DNS in CMDB + '
        print(str(dns)," DNS in CMDB +")

# %%
connection_check()
# Out:
# <Response [200]>

# %%
start = time.perf_counter()
filename='AMS_PDUS.xlsx'
workbook = pd.ExcelFile(f'{filename}')

# %%
data = pd.read_excel(workbook)

# %%
data['IP in CMDB']=''
data['DNS in CMDB']=''

# %%
with concurrent.futures.ThreadPoolExecutor() as executor:
    executor.map(ip_search, data['IP'])
    executor.map(dns_search, data['DNS'])
# Out:
# 10.16.131.245 IP NOT in CMDB
# 10.16.131.242 IP NOT in CMDB
# 10.16.129.242 IP NOT in CMDB
# 10.16.129.243 IP NOT in CMDB
# 10.16.129.241 IP NOT in CMDB
# 10.16.129.240 IP NOT in CMDB 10.16.131.241 IP NOT in CMDB
#
# 10.16.129.244 IP NOT in CMDB 10.16.129.246 IP NOT in CMDB
#
# 10.16.131.247 IP NOT in CMDB 10.16.131.240 IP NOT in CMDB
#
# 10.16.131.246 IP NOT in CMDB
# 10.16.131.243 IP NOT in CMDB 10.16.129.245 IP NOT in CMDB 10.16.129.247 IP NOT in CMDB
#
#
# 10.16.131.244 IP NOT in CMDB
# <ipython-input-3-876f50fcfeb6>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['IP in CMDB'][data['IP'] == ip] = 'IP NOT in CMDB'
# <ipython-input-3-876f50fcfeb6>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['DNS in CMDB'][data['DNS'] == dns] = 'DNS NOT in CMDB'
# pdu-am3-01-06c.ams.netledger.com  DNS NOT in cmdb
# pdu-am3-01-06b.ams.netledger.com pdu-am3-01-05a.ams.netledger.com DNS NOT in cmdb
#   DNS NOT in cmdb
# pdu-am3-01-06d.ams.netledger.com  DNS NOT in cmdb
# pdu-am3-01-01c.ams.netledger.compdu-am3-01-01b.ams.netledger.com  DNS NOT in cmdb
#   DNS NOT in cmdb
# pdu-am3-01-02a.ams.netledger.com  DNS NOT in cmdb
# pdu-am3-01-02b.ams.netledger.com  DNS NOT in cmdb
# pdu-am3-01-05d.ams.netledger.com  DNS NOT in cmdb
# pdu-am3-01-01a.ams.netledger.com  DNS NOT in cmdb
# pdu-am3-01-05c.ams.netledger.com  DNS NOT in cmdbpdu-am3-01-02c.ams.netledger.com
#   DNS NOT in cmdb
# pdu-am3-01-05b.ams.netledger.com pdu-am3-01-06a.ams.netledger.com DNS NOT in cmdb
#   DNS NOT in cmdb
# pdu-am3-01-02d.ams.netledger.com pdu-am3-01-01d.ams.netledger.com DNS NOT in cmdb
#   DNS NOT in cmdb

# %%
with pd.ExcelWriter(f'{filename}') as writer:
    data.to_excel(writer, index=False)

print(f"{filename} has been exported")
stop = time.perf_counter()

print("It took "+str(round((stop-start)/60,2))+" minutes for the script to complete")
# Out:
# AMS_PDUS.xlsx has been exported
# It took 0.1 minutes for the script to complete

# %%
data
# Out:
#                IP                                DNS Tracking Method  \
# 0    10.6.155.241   pdu-se4-07-08b.sea.netledger.com              IP
# 1   10.30.157.242  pdu-se4c-01-11c.sea.netledger.com              IP
# 2    10.3.155.245   pdu-se4-03-02b.sea.netledger.com              IP
# 3   10.30.160.244  pdu-se4c-02-11a.sea.netledger.com              IP
# 4   10.30.158.240  pdu-se4c-02-06a.sea.netledger.com              IP
# 5    10.3.178.231  pdu-se4b-04-01d.sea.netledger.com              IP
# 6    10.3.178.198  pdu-se4b-01-02d.sea.netledger.com              IP
# 7    10.6.155.243   pdu-se4-07-08d.sea.netledger.com              IP
# 8   10.30.158.247  pdu-se4c-02-05d.sea.netledger.com              IP
# 9   10.30.158.242  pdu-se4c-02-06c.sea.netledger.com              IP
# 10   10.6.156.243   pdu-se4-07-10d.sea.netledger.com              IP
# 11   10.3.106.241   pdu-se4-05-05b.sea.netledger.com              IP
# 12   10.3.106.244   pdu-se4-05-06a.sea.netledger.com              IP
#
#    Last Scanned Date                                               Tags From  \
# 0         2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_loc_SE4|AG:IL...  PCP
# 1         2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_loc_SE4|AG:IL...  PCP
# 2         2021-01-16  AG:IL_role_pdu|AG:IL_automation_NSCORE|AG:se4_...  PCP
# 3         2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_loc_SE4|AG:IL...  PCP
# 4         2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_loc_SE4|AG:IL...  PCP
# 5         2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_loc_SE4|AG:IL...  PCP
# 6         2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_loc_SE4|AG:se...  PCP
# 7         2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_loc_SE4|AG:se...  PCP
# 8         2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_loc_SE4|AG:IL...  PCP
# 9         2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_loc_SE4|AG:IL...  PCP
# 10        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_loc_SE4|AG:IL...  PCP
# 11        2020-10-10  AG:IL_loc_SE4|AG:IL_env_Admin Env|AG:IL_app_Bl...  PCP
# 12        2020-10-10  BU:NSCore|AG:IL_automation|AG:IL_loc_SE4|AG:IL...  PCP
#
#     IP in CMDB  DNS in CMDB  VM host URL  Ping  \
# 0   IP in CMDB  DNS in CMDB          NaN  DOWN
# 1   IP in CMDB  DNS in CMDB          NaN  DOWN
# 2   IP in CMDB  DNS in CMDB          NaN  DOWN
# 3   IP in CMDB  DNS in CMDB          NaN  DOWN
# 4   IP in CMDB  DNS in CMDB          NaN  DOWN
# 5   IP in CMDB  DNS in CMDB          NaN  DOWN
# 6   IP in CMDB  DNS in CMDB          NaN  DOWN
# 7   IP in CMDB  DNS in CMDB          NaN  DOWN
# 8   IP in CMDB  DNS in CMDB          NaN  DOWN
# 9   IP in CMDB  DNS in CMDB          NaN  DOWN
# 10  IP in CMDB  DNS in CMDB          NaN  DOWN
# 11  IP in CMDB  DNS in CMDB          NaN  DOWN
# 12  IP in CMDB  DNS in CMDB          NaN  DOWN
#
#                                  CNAME
# 0    pdu-se4-07-08b.sea.netledger.com.
# 1   pdu-se4c-01-11c.sea.netledger.com.
# 2    pdu-se4-03-02b.sea.netledger.com.
# 3   pdu-se4c-02-11a.sea.netledger.com.
# 4   pdu-se4c-02-06a.sea.netledger.com.
# 5   pdu-se4b-04-01d.sea.netledger.com.
# 6   pdu-se4b-01-02d.sea.netledger.com.
# 7    pdu-se4-07-08d.sea.netledger.com.
# 8   pdu-se4c-02-05d.sea.netledger.com.
# 9   pdu-se4c-02-06c.sea.netledger.com.
# 10   pdu-se4-07-10d.sea.netledger.com.
# 11   pdu-se4-05-05b.sea.netledger.com.
# 12   pdu-se4-05-06a.sea.netledger.com.
