# %%
import pandas as pd
import os,shutil, requests, time
import concurrent.futures
start = time.perf_counter()

# %%
workbook = pd.ExcelFile('latest_sample_pinged_data.xlsx')

# %%
data = pd.read_excel(workbook)

# %%
data = data.sort_values('Last Scanned Date',ascending=False).drop_duplicates('IP', keep='last')

# %%
cy = data[data['DNS'].str.contains('-cy', na=False)]

# %%
not_cy = cy[cy['DNS in CMDB']=='DNS NOT in CMDB']

# %%
svale = not_cy[not_cy['DNS'].str.contains('svale',na=False)]
sea = not_cy[not_cy['DNS'].str.contains('sea',na=False)]
bos = not_cy[not_cy['DNS'].str.contains('bos',na=False)]
ams = not_cy[not_cy['DNS'].str.contains('ams',na=False)]
chi = not_cy[not_cy['DNS'].str.contains('chi',na=False)]
dub = not_cy[not_cy['DNS'].str.contains('dub',na=False)]

# %%
frames = [sea,bos,ams,chi,dub]
sheets = ['SEA','BOS','AMS','CHI','DUB']

# %%
with pd.ExcelWriter('Cyclades_not_in_CMDB.xlsx') as writer:
    for frame,sheet in zip(frames,sheets):
        if len(frame) > 0:
            frame.to_excel(writer,sheet_name=sheet, index=False)

# %%
print("Cyclades_not_in_CMDB has been exported")
stop = time.perf_counter()
print("It took "+str(round((stop-start)/60,2))+" minutes for the script to complete")
# Out:
# Cyclades_not_in_CMDB has been exported
# It took 0.11 minutes for the script to complete
