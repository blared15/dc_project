# %%
import pandas as pd
import os,shutil
from datetime import datetime, timedelta
import datetime

# %%
workbook = pd.ExcelFile('latest_sample_pinged_data.xlsx')

# %%
data = pd.read_excel(workbook)

# %%
len(data)
# Out:
# 57875

# %%
#extracts the filtered data to its own variable
def sheet(source,column, string):
    x = source[source[column].str.contains(string,na=False)]
    x = x.sort_values('IP')
    return x
#removes the filtered data from the main variable
def sheet_x(source,column, string):
    x = source[~source[column].str.contains(string,na=False)]
    x = x.sort_values('IP')
    return x

# %%
#change last scanned date to_date
data['Last Scanned Date']=pd.to_datetime(data['Last Scanned Date'], format= '%Y-%m-%d').dt.date

# %%
#getting duplicates by date
duplicates = data[data.sort_values('Last Scanned Date').duplicated('IP', keep='first')]
# Out:
# /Users/raeniellesunga/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
#dropping duplicates keeping last/recent instance
data = data.sort_values('Last Scanned Date').drop_duplicates('IP', keep='last')

# %%
#older than 30days from last scanned date
old = data[data['Last Scanned Date'] < datetime.date(2021,1,19)- pd.to_timedelta("30day") ].sort_values('Last Scanned Date' ,ascending=False)

# %%
#30 days from last scanned date
data = data[data['Last Scanned Date'] > datetime.date(2021,1,19)- pd.to_timedelta("30day") ].sort_values('Last Scanned Date' ,ascending=False)

# %%
console = data[data['DNS'].str.contains('console')]

# %%
with pd.ExcelWriter('test_consoles.xlsx') as writer:
    console.to_excel(writer, index=False)

# %%
def cmdb(x):
    ins = x[(x['IP in CMDB']=='IP in CMDB') & (x['DNS in CMDB'] == 'DNS in CMDB')]
    out = x[(x['IP in CMDB'] =='IP NOT in CMDB') & (x['DNS in CMDB'] == 'DNS NOT in CMDB')]
    return ins, out

# %%
def writers(frame, title,typed):
    with pd.ExcelWriter(f'{title}/{typed}_{title}.xlsx') as create:
        print(itle)
        frame.to_excel(create, index=False)

# %%
# filters(data)

# %%
print('Sorting "Duplicate IP"')
duplicate = data[data.duplicated(subset=['IP'],keep='last')]
main = data[~data.duplicated(subset=['IP'],keep='last')]
print('Sorting "Available"')
available = sheet(main,'DNS','available')
main = sheet_x(main,'DNS','available')
available = available.append(sheet(main,'CNAME','AVAILABLE'))
main = sheet_x(main,'CNAME','AVAILABLE')
print('Sorting "VIP DNS"')
vip = sheet(main,'DNS','vip')
main = sheet_x(main,'DNS','vip')
print('Sorting "Internet Facing Assets"')
pub = sheet(main,'Tags','Internet Facing Assets')
main = sheet_x(main,'Tags','Internet Facing Assets')
print('Sorting "Load Balancers"')
lb = sheet(main,'DNS','-mip|-vlb|-plb')
main = sheet_x(main,'DNS','-mip|-vlb|-plb')
#Tags
lb = lb.append(sheet(main,'Tags','loadbalancer'))
main = sheet_x(main,'Tags','loadbalancer')
print('Sorting "Agent"')
agent = sheet(main,'Tracking Method','AGENT')
main = sheet_x(main,'Tracking Method','AGENT')
print('Sorting "Interface"')
interface = sheet(main,'DNS','interface')
main = sheet_x(main,'DNS','interface')
print('Sorting "links"')
link = sheet(main,'DNS','-link')
main = sheet_x(main,'DNS','-link')
print('Sorting "None"')
blank = sheet(main,'DNS','None|none')
main = sheet_x(main,'DNS','None|none')
print('Sorting "DevOps"')
devops = sheet(main,'Tags','BU:DevOps')
main = sheet_x(main,'Tags','BU:DevOps')
print('Sorting "Duplicate DNS"')
duplicate = duplicate.append(main[main.duplicated(subset=['DNS'],keep='last')])
main = main[~main.duplicated(subset=['DNS'],keep='first')]
print('Sorting "LS"')
ls = sheet(main,'DNS','-ls')
main = sheet_x(main,'DNS','-ls')
print('Sorting "CY"')
cy = sheet(main,'DNS','cy')
main = sheet_x(main,'DNS','cy')
print('Sorting "bo1"')
bo1 = sheet(main,'DNS','BO1|bo1')
main = sheet_x(main,'DNS','BO1|bo1')
#Tags
bo1 = bo1.append(sheet(main,'Tags','BO1|bo1'))
main = sheet_x(main,'Tags','BO1|bo1')
print('Sorting "Bronto"')
bronto = sheet(main,'DNS','Bronto|bronto')
main = sheet_x(main,'DNS','Bronto|bronto')
#tags
bronto = bronto.append(sheet(main,'Tags','Bronto|bronto'))
main = sheet_x(main,'Tags','Bronto|bronto')
print('Sorting "OpenAir"')
openair = sheet(main,'Tags','openair|OpenAir')
main = sheet_x(main,'Tags','openair|OpenAir')
print('Sorting "OCI"')
oci = sheet(main,'DNS','OCI|oci')
main = sheet_x(main,'DNS','OCI|oci')
#tags
oci = oci.append(sheet(main,'Tags','OCI|oci'))
main = sheet_x(main,'Tags','OCI|oci')
print('Sorting "Payroll"')
payroll = sheet(main,'Tags','payroll|Payroll')
main = sheet_x(main,'Tags','payroll|Payroll')
print('Sorting "VPN"')
vpn = sheet(main,'DNS','vpn|ovpn')
main = sheet_x(main,'DNS','vpn|ovpn')
#tags
vpn = vpn.append(sheet(main,'Tags','vpn|ovpn'))
main = sheet_x(main,'Tags','vpn|ovpn')
print('Sorting "Console"')
console = sheet(main,'DNS','console')
main = sheet_x(main,'DNS','console')
#tags
console = console.append(sheet(main,'Tags','console'))
main = sheet_x(main,'Tags','console')
print('Sorting "NoUse"')
nouse = sheet(main,'DNS','nouse')
main = sheet_x(main,'DNS','nouse')
print('Sorting "VM"')
vm = sheet(main,'DNS','snap|\.f\.|\.m\.')
main = sheet_x(main,'DNS','snap|\.f\.|\.m\.')
print('Sorting "PDU"')
pdu = sheet(main,'DNS','pdu-')
main = sheet_x(main,'DNS','pdu-')
#IP address filter
pdu = pdu.append(sheet(main,'IP','^10\..*\..*\.24[0-8]'))
main = sheet_x(main,'IP','^10\..*\..*\.24[0-8]')
print('Finished sorting filters')
filter_frame = [main,lb,devops,link, blank, duplicate, agent, ls, cy, pdu, pub, bo1, bronto, openair, oci, payroll, console, vpn, nouse, vm,interface, available,vip]
filter_title = ['main','Load Balancer','DevOps','Link', 'None', 'Duplicate', 'Agent', 'LS', 'CY', 'PDU', 'Internet Facing Asset', 'BO1', 'Bronto', 'OpenAir', 'OCI'
                , 'Payroll', 'Console', 'VPN', 'NoUse', 'VM','Interface', 'Available', 'VIP_NAT']
# Out:
# Sorting "Duplicate IP"
# Sorting "Available"
# Sorting "VIP DNS"
# Sorting "Internet Facing Assets"
# Sorting "Load Balancers"
# Sorting "Agent"
# Sorting "Interface"
# Sorting "links"
# Sorting "None"
# Sorting "DevOps"
# Sorting "Duplicate DNS"
# Sorting "LS"
# Sorting "CY"
# Sorting "bo1"
# Sorting "Bronto"
# Sorting "OpenAir"
# Sorting "OCI"
# Sorting "Payroll"
# Sorting "VPN"
# Sorting "Console"
# Sorting "NoUse"
# Sorting "VM"
# Sorting "PDU"
# Finished sorting filters

# %%
for frame, title in zip(filter_frame, filter_title):
    if len(frame) >0:
        if os.path.exists(title):
            shutil.rmtree(title)
            os.mkdir(title)
        else:
            os.mkdir(title)
        
        ins,out=cmdb(frame)
        if len(ins)>0:
            print (f'{title}_ins,{len(ins)}')
            writers(frame, title,'in_cmdb')
        else:
            pass

        if len(out) >0:
            print (f'{title}_out,{len(out)}')
            writers(frame, title,'out_cmdb')
        else:
            pass
# Out:
# main_ins,5705
# main
# main_out,140
# main
# Load Balancer_ins,36
# Load Balancer
# Load Balancer_out,590
# Load Balancer
# DevOps_out,152
# DevOps
# Link_out,746
# Link
# None_out,12304
# None
# Duplicate_out,4
# Duplicate
# Agent_ins,2912
# Agent
# Agent_out,2679
# Agent
# LS_ins,687
# LS
# LS_out,37
# LS
# CY_ins,75
# CY
# CY_out,134
# CY
# PDU_ins,1094
# PDU
# PDU_out,51
# PDU
# Internet Facing Asset_out,962
# Internet Facing Asset
# BO1_ins,3
# BO1
# BO1_out,3
# BO1
# Bronto_out,1002
# Bronto
# OpenAir_out,78
# OpenAir
# OCI_ins,10
# OCI
# OCI_out,10
# OCI
# Console_ins,29
# Console
# Console_out,4945
# Console
# VPN_ins,20
# VPN
# VPN_out,5028
# VPN
# NoUse_out,295
# NoUse
# VM_ins,852
# VM
# VM_out,99
# VM
# Interface_out,2720
# Interface
# Available_ins,12
# Available
# Available_out,4687
# Available
# VIP_NAT_out,511
# VIP_NAT

# %%
ins, out = cmdb(vm)

# %%
total = []

# %%
for x,y in zip(filter_frame,filter_title):
    total.append(len(x))
    print(len(x),y)
# Out:
# 5928 main
# 626 Load Balancer
# 152 DevOps
# 746 Link
# 12325 None
# 4 Duplicate
# 6410 Agent
# 743 LS
# 276 CY
# 1380 PDU
# 1268 Internet Facing Asset
# 6 BO1
# 1007 Bronto
# 78 OpenAir
# 20 OCI
# 0 Payroll
# 4974 Console
# 5049 VPN
# 295 NoUse
# 959 VM
# 2720 Interface
# 4741 Available
# 519 VIP_NAT

# %%
oci
# Out:
#                  IP                                       DNS Tracking Method  \
# 33377  10.12.182.64  ocitx001-console.adm.svale.netledger.com              IP
# 33378  10.12.182.65  ocitx002-console.adm.svale.netledger.com              IP
# 33423  10.12.182.66  ocitx003-console.adm.svale.netledger.com              IP
# 33451  10.12.182.67  ocitx004-console.adm.svale.netledger.com              IP
# 33198  10.12.182.68  ocitx005-console.adm.svale.netledger.com              IP
# 33382  10.12.186.31  ocitx006-console.adm.svale.netledger.com              IP
# 33476  10.12.186.32  ocitx007-console.adm.svale.netledger.com              IP
# 33230  10.12.186.33  ocitx008-console.adm.svale.netledger.com              IP
# 33383  10.12.186.34  ocitx009-console.adm.svale.netledger.com              IP
# 33324  10.12.186.35  ocitx010-console.adm.svale.netledger.com              IP
# 31543   10.12.54.64          ocitx001.adm.svale.netledger.com              IP
# 31814   10.12.54.65          ocitx002.adm.svale.netledger.com              IP
# 31544   10.12.54.66          ocitx003.adm.svale.netledger.com              IP
# 31815   10.12.54.67          ocitx004.adm.svale.netledger.com              IP
# 31545   10.12.54.68          ocitx005.adm.svale.netledger.com              IP
# 31869   10.12.58.31          ocitx006.adm.svale.netledger.com              IP
# 31870   10.12.58.32          ocitx007.adm.svale.netledger.com              IP
# 31871   10.12.58.33          ocitx008.adm.svale.netledger.com              IP
# 31872   10.12.58.34          ocitx009.adm.svale.netledger.com              IP
# 31565   10.12.58.35          ocitx010.adm.svale.netledger.com              IP
#
#       Last Scanned Date                                               Tags  \
# 33377        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
# 33378        2021-01-16  AG:IL_automation_NSCORE|AG:sc9_internal_all|BU...
# 33423        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
# 33451        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
# 33198        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
# 33382        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
# 33476        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
# 33230        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
# 33383        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
# 33324        2021-01-16  AG:IL_automation_NSCORE|AG:sc9_internal_all|BU...
# 31543        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
# 31814        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
# 31544        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
# 31815        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
# 31545        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
# 31869        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
# 31870        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
# 31871        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
# 31872        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
# 31565        2021-01-16  BU:NSCore|AG:IL_automation|AG:IL_env_Admin Env...
#
#       From      IP in CMDB      DNS in CMDB VM host URL  Ping  \
# 33377  PCP  IP NOT in CMDB  DNS NOT in CMDB         NaN  DOWN
# 33378  PCP  IP NOT in CMDB  DNS NOT in CMDB         NaN  DOWN
# 33423  PCP  IP NOT in CMDB  DNS NOT in CMDB         NaN  DOWN
# 33451  PCP  IP NOT in CMDB  DNS NOT in CMDB         NaN  DOWN
# 33198  PCP  IP NOT in CMDB  DNS NOT in CMDB         NaN  DOWN
# 33382  PCP  IP NOT in CMDB  DNS NOT in CMDB         NaN  DOWN
# 33476  PCP  IP NOT in CMDB  DNS NOT in CMDB         NaN  DOWN
# 33230  PCP  IP NOT in CMDB  DNS NOT in CMDB         NaN  DOWN
# 33383  PCP  IP NOT in CMDB  DNS NOT in CMDB         NaN  DOWN
# 33324  PCP  IP NOT in CMDB  DNS NOT in CMDB         NaN  DOWN
# 31543  PCP      IP in CMDB      DNS in CMDB         NaN  DOWN
# 31814  PCP      IP in CMDB      DNS in CMDB         NaN  DOWN
# 31544  PCP      IP in CMDB      DNS in CMDB         NaN  DOWN
# 31815  PCP      IP in CMDB      DNS in CMDB         NaN  DOWN
# 31545  PCP      IP in CMDB      DNS in CMDB         NaN  DOWN
# 31869  PCP      IP in CMDB      DNS in CMDB         NaN  DOWN
# 31870  PCP      IP in CMDB      DNS in CMDB         NaN  DOWN
# 31871  PCP      IP in CMDB      DNS in CMDB         NaN  DOWN
# 31872  PCP      IP in CMDB      DNS in CMDB         NaN  DOWN
# 31565  PCP      IP in CMDB      DNS in CMDB         NaN  DOWN
#
#                                            CNAME
# 33377  ocitx001-console.adm.svale.netledger.com.
# 33378  ocitx002-console.adm.svale.netledger.com.
# 33423  ocitx003-console.adm.svale.netledger.com.
# 33451  ocitx004-console.adm.svale.netledger.com.
# 33198  ocitx005-console.adm.svale.netledger.com.
# 33382  ocitx006-console.adm.svale.netledger.com.
# 33476  ocitx007-console.adm.svale.netledger.com.
# 33230  ocitx008-console.adm.svale.netledger.com.
# 33383  ocitx009-console.adm.svale.netledger.com.
# 33324  ocitx010-console.adm.svale.netledger.com.
# 31543          ocitx001.adm.svale.netledger.com.
# 31814          ocitx002.adm.svale.netledger.com.
# 31544          ocitx003.adm.svale.netledger.com.
# 31815          ocitx004.adm.svale.netledger.com.
# 31545          ocitx005.adm.svale.netledger.com.
# 31869          ocitx006.adm.svale.netledger.com.
# 31870          ocitx007.adm.svale.netledger.com.
# 31871          ocitx008.adm.svale.netledger.com.
# 31872          ocitx009.adm.svale.netledger.com.
# 31565          ocitx010.adm.svale.netledger.com.

# %%
print(filter_title)
# Out:
# ['main', 'Load Balancer', 'DevOps', 'Link', 'None', 'Duplicate', 'Agent', 'LS', 'CY', 'PDU', 'Internet Facing Asset', 'BO1', 'Bronto', 'OpenAir', 'OCI', 'Payroll', 'Console', 'VPN', 'NoUse', 'VM', 'Interface', 'Available', 'VIP_NAT']

# %%
with pd.ExcelWriter('test.xlsx') as writer:
    ins.to_excel(writer,sheet_name='vm_in', index=False)
    out.to_excel(writer,sheet_name='vm_out', index=False)

# %%
    
    
        
# with pd.ExcelWriter('test.xlsx') as writer:
#     main.to_excel(writer,sheet_name='main', index=False)
#     agent.to_excel(writer,sheet_name='AGENT', index=False)
#     netops.to_excel(writer,sheet_name='netops', index=False)
#     nscore.to_excel(writer,sheet_name='nscore', index=False)
#     bronto.to_excel(writer,sheet_name='bronto', index=False)
#     openair.to_excel(writer,sheet_name='openair', index=False)
#     payroll.to_excel(writer,sheet_name='payroll', index=False)
#     devops.to_excel(writer,sheet_name='devops', index=False)
#     pub.to_excel(writer,sheet_name='Internet Facing Assets', index=False)
#     nspos.to_excel(writer,sheet_name='NSPOS', index=False)
#     test_asset.to_excel(writer,sheet_name='Test Asset', index=False)
#     legacy.to_excel(writer,sheet_name='LegacyCorp', index=False)
