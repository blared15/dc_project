# %%
import os, time, concurrent.futures, shutil,requests
import pandas as pd
columns = shutil.get_terminal_size().columns

# %%
title = (r"""
  _____  _____     ____                            
 |_   _||  __ \   / __ \                           
   | |  | |__) | | |  | | _   _   ___  _ __  _   _ 
   | |  |  ___/  | |  | || | | | / _ \| '__|| | | |
  _| |_ | |      | |__| || |_| ||  __/| |   | |_| |
 |_____||_|       \___\_\ \__,_| \___||_|    \__, |
                                              __/ |
                                             |___/ 
""")

# %%
print(title)
# Out:
#   _____  _____     ____
#  |_   _||  __ \   / __ \
#    | |  | |__) | | |  | | _   _   ___  _ __  _   _
#    | |  |  ___/  | |  | || | | | / _ \| '__|| | | |
#   _| |_ | |      | |__| || |_| ||  __/| |   | |_| |
#  |_____||_|       \___\_\ \__,_| \___||_|    \__, |
#                                               __/ |
#                                              |___/

# %%
print(title)
print("*".center(columns,'*'))       
print ("This program check if the ip address response to ping.".center(columns))
print("Make sure that you are connected to the VPN.".center(columns))
print("This program will take about ~60 minutes to finish ping the IP list.".center(columns))
print("*".center(columns,'*'))
# Out:
#   _____  _____     ____
#  |_   _||  __ \   / __ \
#    | |  | |__) | | |  | | _   _   ___  _ __  _   _
#    | |  |  ___/  | |  | || | | | / _ \| '__|| | | |
#   _| |_ | |      | |__| || |_| ||  __/| |   | |_| |
#  |_____||_|       \___\_\ \__,_| \___||_|    \__, |
#                                               __/ |
#                                              |___/
#
# ********************************************************************************
#              This program check if the ip address response to ping.
#                   Make sure that you are connected to the VPN.
#       This program will take about ~60 minutes to finish ping the IP list.
# ********************************************************************************

# %%
def main_ping(ip):
    response = os.popen(f"ping -c 1 {ip}").read()
    if "Received = 4" in response:
        print(f"UP {ip} Ping Successful")
        data['Ping'][data['IP']==ip]='UP'
    else:
        print(f"DOWN {ip} Ping Unsuccessful")
        data['Ping'][data['IP']==ip]='DOWN'
def main_lookup(ip):
    response = os.popen("nslookup "+ ip+" | awk 'NR==5{print $4}'").read()
    if response == '\n':
        print(f"{ip} No DNS")
        data['CNAME'][data['IP']==ip]='None'
    else:
        print(f"{ip} {response}")
        response = response.rstrip()
        data['CNAME'][data['IP']==ip]=response

def file_check(file_name):
    check = os.path.isfile(file_name)
    file_name = file_name +".xlsx"
    while check == False:
        file_name = input("File name not found.\n Enter XLSX file that contains the merged files (no tabs) without the file extension. ex: ~/Downloads/raw_data :\n")
        check = os.path.isfile(file_name)
    print( " file found: " + str(check))    

def connection_check():
    API = '0a66e9aecdc8c49191309691d8c340b920a060b3'
    endpoint = 'https://cmdb.netledger.com/api/dc-hosts/'
    headers = {'Authorization': 'Token '+ API}
    response = requests.get(endpoint, headers=headers)
    print (response)

# %%
file_name = input("Enter XLSX file that contains the merged files (no tabs) without the file extension. ex: ~/Downloads/raw_data :\n")
file_name = file_name +".xlsx"
file_check(file_name)
print("Checking VPN connection: ")
connection_check()

start = time.perf_counter()
data = pd.read_excel(file_name)
data['Ping']=''
data['CNAME']=''

# %%
data
# Out:
#                    IP                         DNS Tracking Method  \
# 0         64.89.45.26       rest.na1.netsuite.com              IP
# 1         64.89.44.97   suiteconnect.netsuite.com              IP
# 2         64.89.44.98                        None              IP
# 3         64.89.44.99                        None              IP
# 4        64.89.44.101                        None              IP
# ...               ...                         ...             ...
# 57870   172.17.42.155                   se4-kms01           AGENT
# 57871    172.17.42.40              sc8-mailmgmt01           AGENT
# 57872   172.17.42.134                 sc8-scanner           AGENT
# 57873  192.168.201.34  radchikov.brontolabs.local           AGENT
# 57874  192.168.201.34  radchikov.brontolabs.local           AGENT
#
#       Last Scanned Date                                               Tags  \
# 0            2021-01-19  bo1_external_all|all_external|LightCMS|BU:NSCo...
# 1            2021-01-19  bo1_external_all|bo1_lightcms_external_all|all...
# 2            2021-01-19  bo1_external_all|bo1_lightcms_external_all|all...
# 3            2021-01-19  bo1_external_all|bo1_lightcms_external_all|all...
# 4            2021-01-19  bo1_external_all|bo1_lightcms_external_all|all...
# ...                 ...                                                ...
# 57870        2021-01-19                       NSIT Cloud Agent|Cloud Agent
# 57871        2021-01-19                       NSIT Cloud Agent|Cloud Agent
# 57872        2021-01-19                       NSIT Cloud Agent|Cloud Agent
# 57873        2021-01-19                     Bronto Cloud Agent|Cloud Agent
# 57874        2021-01-19                     Cloud Agent|Bronto Cloud Agent
#
#         From      IP in CMDB      DNS in CMDB VM host URL Ping CNAME
# 0      Cloud  IP NOT in CMDB  DNS NOT in CMDB         NaN
# 1      Cloud  IP NOT in CMDB  DNS NOT in CMDB         NaN
# 2      Cloud  IP NOT in CMDB  DNS NOT in CMDB         NaN
# 3      Cloud  IP NOT in CMDB  DNS NOT in CMDB         NaN
# 4      Cloud  IP NOT in CMDB  DNS NOT in CMDB         NaN
# ...      ...             ...              ...         ...  ...   ...
# 57870    PCP  IP NOT in CMDB  DNS NOT in CMDB         NaN
# 57871    PCP  IP NOT in CMDB  DNS NOT in CMDB         NaN
# 57872    PCP  IP NOT in CMDB  DNS NOT in CMDB         NaN
# 57873    PCP  IP NOT in CMDB  DNS NOT in CMDB         NaN
# 57874    PCP  IP NOT in CMDB  DNS NOT in CMDB         NaN
#
# [57875 rows x 11 columns]

# %%
with concurrent.futures.ThreadPoolExecutor() as executor:
    executor.map(main_ping,data['IP'])
    executor.map(main_lookup,data['IP'])
# Out:
# DOWN 10.16.131.245 Ping Unsuccessful
# DOWN 10.16.131.240 Ping Unsuccessful
# DOWN 10.16.131.247 Ping Unsuccessful
# DOWN 10.16.131.246 Ping Unsuccessful
# <ipython-input-13-be159ee1da84>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Ping'][data['IP']==ip]='DOWN'
# DOWN 10.16.129.241 Ping Unsuccessful
# DOWN 10.16.129.242 Ping Unsuccessful
# DOWN 10.16.129.244 Ping Unsuccessful
# DOWN 10.16.129.247 Ping Unsuccessful
# DOWN 10.16.129.245 Ping Unsuccessful
# DOWN 10.16.131.244 Ping Unsuccessful
# DOWN 10.16.129.240 Ping Unsuccessful
# DOWN 10.16.129.243 Ping Unsuccessful
# DOWN 10.16.131.243 Ping Unsuccessful
# DOWN 10.16.131.242 Ping Unsuccessful
# 10.16.131.247
# 10.16.129.246 10.16.131.246 10.16.129.240 10.16.131.245
#
#
# 10.16.131.240
# 10.16.129.242 10.16.131.243 10.16.129.244
#
# 10.16.131.242
#
#
# 10.16.131.241
# 10.16.129.245
# 10.16.129.243
# <ipython-input-13-be159ee1da84>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['CNAME'][data['IP']==ip]=response
# 10.16.129.247 10.16.131.244
#
# 10.16.129.241
# DOWN 10.16.129.246 Ping Unsuccessful
# DOWN 10.16.131.241 Ping Unsuccessful

# %%
with pd.ExcelWriter('Latest_pinged_data.xlsx') as writer:
    data.to_excel(writer, index=False)

stop = time.perf_counter()

print("It took "+str(round((stop-start)/60,2))+" minutes for the script to complete")
# Out:
# It took 0.4 minutes for the script to complete
